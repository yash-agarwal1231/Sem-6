# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %% [markdown]
# # Example

# %%
x = np.linspace(0,5,100)
y = np.linspace(0,5,100)
X, Y = np.meshgrid(x,y)
Z = np.exp(-X**2 - Y**2)
fig = plt.figure(figsize = (8,7))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin(x+y)')
plt.show()

# %% [markdown]
# # Q1

# %%
x = np.linspace(0,2*np.pi,100)
y = np.linspace(0,2*np.pi,100)
X, Y = np.meshgrid(x,y)
Z = X**3 + Y**2
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin(x+y)')
plt.show()

# %% [markdown]
# # Q2

# %%
x = np.linspace(-2*np.pi,2*np.pi,100)
y = np.linspace(-2*np.pi,2*np.pi,100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X**2 + Y)
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin(x+y)')
plt.show()

# %% [markdown]
# # Q3

# %%
x = np.linspace(-2*np.pi,2*np.pi,100)
y = np.linspace(-2*np.pi,2*np.pi,100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X + Y) + np.cos(X)
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin(x+y)')
plt.show()

# %% [markdown]
# # Q4

# %%
x = np.linspace(-2*np.pi,2*np.pi,100)
y = np.linspace(-2*np.pi,2*np.pi,100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X) + np.cos(X)
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin x + cos x')
plt.show()

# %% [markdown]
# # Q5

# %%
x = np.linspace(-6,6,100)
y = np.linspace(-6,6,100)
X, Y = np.meshgrid(x,y)
Z = np.sin(X**2 + Y**2)
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin x + cos x')
plt.show()

# %% [markdown]
# # Q6

# %%
x = np.linspace(-6,6,100)
y = np.linspace(-6,6,100)
X, Y = np.meshgrid(x,y)
Z = X**2 + Y**2
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin x + cos x')
plt.show()

# %% [markdown]
# # Q7

# %%
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
X, Y = np.meshgrid(x,y)
Z = np.exp(-X**2 - Y**2)
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = sin x + cos x')
plt.show()

# %% [markdown]
# # Q8

# %%
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
X, Y = np.meshgrid(x,y)
Z = (np.sin(4*X) - np.cos(5*Y)) / 5
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap ='viridis')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3D Contour Plot of f(x,y) = Z = (4*np.sin(X) - 5*np.cos(Y)) / 5')
plt.show()
