# %%
from sympy import *
import matplotlib.pyplot as plt
import math

# %%
P = RegularPolygon((0,0),1,n=5)
P.center
# Out:
# Point2D(0, 0)

# %%
p1,p2,p3,p4 = map(Point,[(0,0),(1,0),(5,1),(0,1)])
P = Polygon(p1,p2,p3,p4)
print(P)
P.area
P.angles[p2]
P.is_convex()
P.perimeter
P.centre
# Out:
# Polygon(Point2D(0, 0), Point2D(1, 0), Point2D(5, 1), Point2D(0, 1))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 8
#       6 P.is_convex()
#       7 P.perimeter
# ----> 8 P.centre
#
# AttributeError: 'Polygon' object has no attribute 'centre'

# %%
p1,p2,p3,p4 = map(Point,[(0,0),(1,0),(5,1),(0,1)])
P = Polygon(p1,p2,p3,p4)
x,y =  symbols('x,y')
L = Line(x+2*y+3)
P1 = P.reflect(L)
P1
# Out:
# Polygon(Point2D(-6/5, -12/5), Point2D(-3/5, -16/5), Point2D(1, -7), Point2D(-2, -3))

# %%
p1,p2,p3,p4 = map(Point,[(0,0),(1,0),(5,1),(0,1)])
P = Polygon(p1,p2,p3,p4)
P.rotate(pi/4)
# Out:
# Polygon(Point2D(0, 0), Point2D(sqrt(2)/2, sqrt(2)/2), Point2D(2*sqrt(2), 3*sqrt(2)), Point2D(-sqrt(2)/2, sqrt(2)/2))

# %%
p1,p2,p3 = map(Point,[(0,0),(1,0),(5,1)])
P = Triangle(p1,p2,p3)
P
# Out:
# Triangle(Point2D(0, 0), Point2D(1, 0), Point2D(5, 1))

# %%
T = Triangle(sss=(3,4,5))
print(T)
# Out:
# Triangle(Point2D(0, 0), Point2D(3, 0), Point2D(3, 4))

# %%
T = Triangle(sas=(3,pi/6,5))
print(T)
# Out:
# Triangle(Point2D(0, 0), Point2D(5, 0), Point2D(3*cos(pi**2/1080), 3*sin(pi**2/1080)))

# %%
T = Triangle(asa=(pi/4,4,pi/6))
print(T)
# Out:
# Triangle(Point2D(0, 0), Point2D(4, 0), Point2D(4*tan(pi**2/1080)/(tan(pi**2/1080) + tan(pi**2/720)), 4*sin(pi**2/1080)*sin(pi**2/720)/sin(pi**2/432)))

# %% [markdown]
# # Assignment 6

# %% [markdown]
# # Q1

# %%
p1,p2,p3,p4 = map(Point,[(0,0),(1,0),(2,2),(1,4)])
P = Polygon(p1,p2,p3,p4)
print("Area = ",P.area)
print("Perimeter = ",P.perimeter)
# Out:
# Area =  4
# Perimeter =  1 + sqrt(17) + 2*sqrt(5)

# %% [markdown]
# # Q2

# %%
P = RegularPolygon((0,0),5,n=8)
print("Area = ",P.area)
print("Perimeter = ",P.perimeter)
# Out:
# Area =  (400 - 200*sqrt(2))/(-4 + 4*sqrt(2))
# Perimeter =  40*sqrt(2 - sqrt(2))

# %% [markdown]
# # Q3

# %%
x,y = symbols('x,y')
P = RegularPolygon((2,2),1.5,n=7)
L = Line(x-y-5)
P1 = P.reflect(L)
P1
# Out:
# RegularPolygon(Point2D(7, -3), -1.50000000000000, 7, 3*pi/14)

# %% [markdown]
# # Q4

# %%
p1,p2,p3,p4 = map(Point,[(0,0),(2,0),(2,3),(1,6)])
P = Polygon(p1,p2,p3,p4)
p1 = P.rotate(math.radians(180))
p1
# Out:
# Polygon(Point2D(0, 0), Point2D(-2, 244929359829471/1000000000000000000000000000000), Point2D(-2, -3), Point2D(-1, -6))

# %% [markdown]
# # Q5

# %%
y = symbols('y')
p1,p2,p3 = map(Point,[(1,0),(2,-1),(-1,3)])
P = Polygon(p1,p2,p3)
L = Line(3-y)
p1 = P.reflect(L)
p1
# Out:
# Triangle(Point2D(1, 6), Point2D(2, 7), Point2D(-1, 3))

# %% [markdown]
# # Q6

# %%
p1,p2,p3 = map(Point,[(0,0),(2,2),(0,2)])
P = Polygon(p1,p2,p3)
print("P1 : ",P.angles[p1])
print("P2 : ",P.angles[p2])
print("P3 : ",P.angles[p3])
# Out:
# P1 :  pi/4
# P2 :  pi/4
# P3 :  pi/2

# %% [markdown]
# # Q7

# %% [markdown]
# ## i)

# %%
p1,p2,p3 = map(Point,[(0,0),(4,0),(2,4)])
P = Triangle(p1,p2,p3)
print("Isosceles : ",P.is_isosceles())
print("Right Angle : ",P.is_right())
print("Scalene : ",P.is_scalene())
# Out:
# Isosceles :  True
# Right Angle :  False
# Scalene :  False

# %% [markdown]
# ## ii)

# %%
p1,p2,p3 = map(Point,[(0,0),(4,0),(4,3)])
P = Triangle(p1,p2,p3)
print("Isosceles : ",P.is_isosceles())
print("Right Angle : ",P.is_right())
print("Scalene : ",P.is_scalene())
# Out:
# Isosceles :  False
# Right Angle :  True
# Scalene :  True

# %% [markdown]
# ## iii)

# %%
p1,p2,p3 = map(Point,[(0,0),(4,0),(1,4)])
P = Triangle(p1,p2,p3)
print("Isosceles : ",P.is_isosceles())
print("Right Angle : ",P.is_right())
print("Scalene : ",P.is_scalene())
# Out:
# Isosceles :  False
# Right Angle :  False
# Scalene :  True

# %% [markdown]
# # Q8

# %% [markdown]
# ## i)

# %%
T = Triangle(sss=(3,4,5))
T
# Out:
# Triangle(Point2D(0, 0), Point2D(3, 0), Point2D(3, 4))

# %% [markdown]
# ## ii)

# %%
T =  Triangle(asa=(math.radians(30),1,math.radians(30)))
T
# Out:
# Triangle(Point2D(0, 0), Point2D(1, 0), Point2D(-tan(0.997091117913343*pi)/(-tan(0.997091117913343*pi) + tan(0.00290888208665722*pi)), sin(0.00290888208665722*pi)*sin(0.997091117913343*pi)/sin(0.994182235826686*pi)))

# %% [markdown]
# ## iii)

# %%
T = Triangle(sas=(1,math.radians(45),2))
T
# Out:
# Triangle(Point2D(0, 0), Point2D(2, 0), Point2D(cos(218166156499291*pi/50000000000000000), sin(218166156499291*pi/50000000000000000)))
