# %% [markdown]
# # SET-A

# %% [markdown]
# # Q1

# %%
import nltk
import re
import heapq
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/tycs18/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/tycs18/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = """Artificial Intelligence is transforming the world. It is used in healthcare, education, and finance. 
AI helps doctors detect disease early. Many companies use AI to improve customer service. However, there are concerns 
about privacy and job loss"""

formatted_text = re.sub('[^a-zA-Z]',' ', text)
#print(formatted_text)
formatted_text = formatted_text.lower()
#print(formatted_text)

words = word_tokenize(formatted_text)
#words

stop_words = set(stopwords.words("english"))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
word_frequencies = {}
for word in words:
    if word not in stop_words:
        word_frequencies[word] = word_frequencies.get(word,0)+1
word_frequencies
# Out:
# {'artificial': 1,
#  'intelligence': 1,
#  'transforming': 1,
#  'world': 1,
#  'used': 1,
#  'healthcare': 1,
#  'education': 1,
#  'finance': 1,
#  'ai': 2,
#  'helps': 1,
#  'doctors': 1,
#  'detect': 1,
#  'disease': 1,
#  'early': 1,
#  'many': 1,
#  'companies': 1,
#  'use': 1,
#  'improve': 1,
#  'customer': 1,
#  'service': 1,
#  'however': 1,
#  'concerns': 1,
#  'privacy': 1,
#  'job': 1,
#  'loss': 1}

# %%
maximum_freq = max(word_frequencies.values())
for word in word_frequencies:
    word_frequencies[word] /= maximum_freq

maximum_freq
# Out:
# 2

# %%
sentences = sent_tokenize(text)
sentence_scores = {}

for sentence in sentences:
    for word in word_tokenize(sentence.lower()):
        if word in word_frequencies:
            sentence_scores[sentence] = sentence_scores.get(sentence, 0) + word_frequencies[word]

sentence_scores
# Out:
# {'Artificial Intelligence is transforming the world.': 2.0,
#  'It is used in healthcare, education, and finance.': 2.0,
#  'AI helps doctors detect disease early.': 3.5,
#  'Many companies use AI to improve customer service.': 4.0,
#  'However, there are concerns \nabout privacy and job loss': 2.5}

# %%
summary_sentences = heapq.nlargest(2,sentence_scores, key = sentence_scores.get)
summary = " ".join(summary_sentences)
print(summary)
# Out:
# Many companies use AI to improve customer service. AI helps doctors detect disease early.

# %% [markdown]
# # Q2

# %%
import nltk
import matplotlib.pyplot as plt
from nltk.probability import FreqDist
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

nltk.download('stopwords')


text = """Python is a powerful programming language. Python is easy to learn & widely used in DS. DS is growing rapidly."""

Sentences = sent_tokenize(text)
words = word_tokenize(text)

filtered_words = [word for word in words if word.lower() not in stop_words and word.isalpha()]

freq_dist = FreqDist(filtered_words)
freq_dist.plot(10)
plt.show()

wordcloud = WordCloud(background_color = 'black').generate(" ".join(filtered_words))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /home/tycs18/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
wordcloud = WordCloud(background_color = 'black').generate(" ".join(filtered_words))

plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Q3

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/tycs18/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()

reviews = ["I purchased headphones online. I am very happy with the product",
           "I saw the movie yesterday. The Animation was really good but script was OK",
           "I enjoy listening to music",
           "I take a walk in the park everyday"
          ]

for review in reviews:
    score = sia.polarity_scores(review)
    print(review)
    print(score)
# Out:
# I purchased headphones online. I am very happy with the product
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6115}
# I saw the movie yesterday. The Animation was really good but script was OK
# {'neg': 0.0, 'neu': 0.647, 'pos': 0.353, 'compound': 0.7181}
# I enjoy listening to music
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4939}
# I take a walk in the park everyday
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %% [markdown]
# # SET B

# %% [markdown]
# # Q2

# %%
import pandas as pd

data = pd.read_csv("covid_2021_1.csv")
data
# Out:
#                                         query  \
# 0     coronavirus|covid%7C19|pandemic|vaccine
# 1     coronavirus|covid%7C19|pandemic|vaccine
# 2     coronavirus|covid%7C19|pandemic|vaccine
# 3     coronavirus|covid%7C19|pandemic|vaccine
# 4     coronavirus|covid%7C19|pandemic|vaccine
# ...                                       ...
# 2721  coronavirus|covid%7C19|pandemic|vaccine
# 2722  coronavirus|covid%7C19|pandemic|vaccine
# 2723  coronavirus|covid%7C19|pandemic|vaccine
# 2724  coronavirus|covid%7C19|pandemic|vaccine
# 2725  coronavirus|covid%7C19|pandemic|vaccine
#
#                                               url  \
# 0     https://www.youtube.com/watch?v=LyRoIKjmk9o
# 1     https://www.youtube.com/watch?v=LyRoIKjmk9o
# 2     https://www.youtube.com/watch?v=LyRoIKjmk9o
# 3     https://www.youtube.com/watch?v=LyRoIKjmk9o
# 4     https://www.youtube.com/watch?v=dwMWM1F7NMI
# ...                                           ...
# 2721  https://www.youtube.com/watch?v=WvYwX9WMzGM
# 2722  https://www.youtube.com/watch?v=2ewylBbJhxs
# 2723  https://www.youtube.com/watch?v=2ewylBbJhxs
# 2724  https://www.youtube.com/watch?v=2ewylBbJhxs
# 2725  https://www.youtube.com/watch?v=2ewylBbJhxs
#
#                                                   title           upload_date  \
# 0     Which Coronavirus Vaccine Is More Effective? C...  2021-01-01T09:04:16Z
# 1     Which Coronavirus Vaccine Is More Effective? C...  2021-01-01T09:04:16Z
# 2     Which Coronavirus Vaccine Is More Effective? C...  2021-01-01T09:04:16Z
# 3     Which Coronavirus Vaccine Is More Effective? C...  2021-01-01T09:04:16Z
# 4     Growing Number Of Americans Going Hungry Durin...  2021-01-01T11:59:49Z
# ...                                                 ...                   ...
# 2721  After Getting COVID Vaccine | Auburn Medical G...  2021-01-05T19:54:45Z
# 2722  "Nobody Said It's A Trial": A New Covid Vaccin...  2021-01-05T20:16:11Z
# 2723  "Nobody Said It's A Trial": A New Covid Vaccin...  2021-01-05T20:16:11Z
# 2724  "Nobody Said It's A Trial": A New Covid Vaccin...  2021-01-05T20:16:11Z
# 2725  "Nobody Said It's A Trial": A New Covid Vaccin...  2021-01-05T20:16:11Z
#
#                    channel  views  likes  dislikes  comment_count  \
# 0              India Today   8276     58         7              5
# 1              India Today   8276     58         7              5
# 2              India Today   8276     58         7              5
# 3              India Today   8276     58         7              5
# 4                 NBC News  74546    874        62            601
# ...                    ...    ...    ...       ...            ...
# 2721  Auburn Medical Group   2129     50         4             12
# 2722                  NDTV  12822    337        23             95
# 2723                  NDTV  12822    337        23             95
# 2724                  NDTV  12822    337        23             95
# 2725                  NDTV  12822    337        23             95
#
#                                            comment_text  \
# 0                                           OMG 😍💋 💝💖❤️
# 1                    I love my Indian Mumbai me welcome
# 2                            What about indian vaccine?
# 3                               2:32 I like that😍💋 💝💖❤️
# 4     And all the rich companies that have profited ...
# ...                                                 ...
# 2721  What do think about people not what the needle...
# 2722                  They are checking it on poor ppl😂
# 2723  Aapke sath ek chota sa prank kiya gaya hai. Ha...
# 2724  I saw another video where the two people they ...
# 2725                                 Kanhaiya and tukde
#
#                    comment_author          comment_date  comment_likes  \
# 0                    Brendan Eric  2021-01-01T09:23:59Z            0.0
# 1     Bhallesingh Rathore rathore  2021-01-01T09:06:51Z            1.0
# 2          Kudip singh hong kong.  2021-02-03T08:17:14Z            0.0
# 3                        Bo Brice  2021-01-01T09:55:34Z            0.0
# 4                     Poppy Jalto  2021-01-01T13:17:56Z           93.0
# ...                           ...                   ...            ...
# 2721              judith marshall  2021-01-13T01:26:29Z            1.0
# 2722            Mohsinmufasa Khan  2021-01-23T19:38:38Z            0.0
# 2723                 Tomato Sauce  2021-01-05T20:46:30Z            3.0
# 2724                        Sneha  2021-01-09T21:41:16Z            0.0
# 2725                          NaN                   NaN            NaN
#
#                            DATE
# 0     2021-01-01 09:04:16+00:00
# 1     2021-01-01 09:04:16+00:00
# 2     2021-01-01 09:04:16+00:00
# 3     2021-01-01 09:04:16+00:00
# 4     2021-01-01 11:59:49+00:00
# ...                         ...
# 2721  2021-01-05 19:54:45+00:00
# 2722  2021-01-05 20:16:11+00:00
# 2723  2021-01-05 20:16:11+00:00
# 2724  2021-01-05 20:16:11+00:00
# 2725                        NaN
#
# [2726 rows x 14 columns]

# %%
data = data.dropna(subset = ['comment_text'])
nltk.download('vader_lexicon')
comments = data['comment_text']

positive = 0
negative = 0
netural = 0

for comment in comments :
    score = sia.polarity_scores(comment)
    if score['compound'] >= 0.05:
        positive += 1
    elif score['compound'] <= 0.05:
        negative += 1
    else :
        neutral += 1

total = positive + negative + netural
print("Positive % : ",100 * positive/total)
print("Negative % : ", 100*negative/total)
print("Neutral % : ", 100*netural/total)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/tycs18/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Positive % :  42.223037417461484
# Negative % :  57.776962582538516
# Neutral % :  0.0

# %% [markdown]
# # Q3

# %%
data = pd.read_csv("INvideos.csv", engine="python", on_bad_lines="skip")
data
# Out:
#         video_id trending_date  \
# 0    kzwfHumJyYc      17.14.11
# 1    zUZ1z7FwLc8      17.14.11
# 2    10L1hZ9qa58      17.14.11
# 3    N1vE8iiEg64      17.14.11
# 4    kJzGH0PVQHQ      17.14.11
# ..           ...           ...
# 702  V2VquEl3zzE      17.17.11
# 703  nNhclTpN_w0      17.17.11
# 704  Fvg3EkAp15E      17.17.11
# 705  Q_FAO1ZNKgo      17.17.11
# 706  KjJ6jg2Zic8      17.17.11
#
#                                                  title  \
# 0    Sharry Mann: Cute Munda ( Song Teaser) | Parmi...
# 1    पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2    Stylish Star Allu Arjun @ ChaySam Wedding Rece...
# 3                       Eruma Saani | Tamil vs English
# 4    why Samantha became EMOTIONAL @ Samantha naga ...
# ..                                                 ...
# 702  Madras Central Gopi'ஐ ரசிப்பேன் - Seeman | Nau...
# 703  Maruvaarthai - Megha Akash Version | Enai Noki...
# 704  #SirPost - Letter To CM (Chinna Mudhalvar)  | ...
# 705       Stephen Has A Drink For Trump... Or Tries To
# 706  5 रुपए की इस चीज़ से बाल लम्बे - घने - मोटे और ...
#
#                           channel_title  category_id  \
# 0                       Lokdhun Punjabi            1
# 1                               HJ NEWS           25
# 2                                  TFPC           24
# 3                           Eruma Saani           23
# 4                            Filmylooks           24
# ..                                  ...          ...
# 702                         Black Sheep           24
# 703                       BehindwoodsTV           24
# 704                        Smile Settai           23
# 705  The Late Show with Stephen Colbert           24
# 706               Ayurved Tips in Hindi           26
#
#                  publish_time  \
# 0    2017-11-12T12:20:39.000Z
# 1    2017-11-13T05:43:56.000Z
# 2    2017-11-12T15:48:08.000Z
# 3    2017-11-12T07:08:48.000Z
# 4    2017-11-13T01:14:16.000Z
# ..                        ...
# 702  2017-11-14T09:31:39.000Z
# 703  2017-11-15T12:11:32.000Z
# 704  2017-11-14T11:47:39.000Z
# 705  2017-11-16T08:35:01.000Z
# 706  2017-11-13T16:31:11.000Z
#
#                                                   tags    views  likes  \
# 0    sharry mann|"sharry mann new song"|"sharry man...  1096327  33966
# 1    पीरियड्स के समय|"पेट पर पति करता ऐसा"|"देखकर द...   590101    735
# 2    Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988   2011
# 3    Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...  1242680  70353
# 4    Filmylooks|"latest news"|"telugu movies"|"telu...   464015    492
# ..                                                 ...      ...    ...
# 702  seeman|"seeman interview"|"madras central"|"pa...   400000  12534
# 703  Maruvaarthai|"Dhanush"|"Megha Akash"|"Ramaguru...   127334   2845
# 704  Sir post|"EPS TRoll"|"Smile settai letter to E...   201800  12508
# 705  The Late Show|"Stephen Colbert"|"Colbert"|"Lat...   597836  10079
# 706  how to grow hair fast|"how to grow hair faster...   885980   4870
#
#      dislikes  comment_count                                  thumbnail_link  \
# 0         798            882  https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg
# 1         904              0  https://i.ytimg.com/vi/zUZ1z7FwLc8/default.jpg
# 2         243            149  https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg
# 3        1624           2684  https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg
# 4         293             66  https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg
# ..        ...            ...                                             ...
# 702       584           1206  https://i.ytimg.com/vi/V2VquEl3zzE/default.jpg
# 703       109            264  https://i.ytimg.com/vi/nNhclTpN_w0/default.jpg
# 704       229           1116  https://i.ytimg.com/vi/Fvg3EkAp15E/default.jpg
# 705       324            855  https://i.ytimg.com/vi/Q_FAO1ZNKgo/default.jpg
# 706      1241            331  https://i.ytimg.com/vi/KjJ6jg2Zic8/default.jpg
#
#      comments_disabled  ratings_disabled  video_error_or_removed  \
# 0                False             False                   False
# 1                 True             False                   False
# 2                False             False                   False
# 3                False             False                   False
# 4                False             False                   False
# ..                 ...               ...                     ...
# 702              False             False                   False
# 703              False             False                   False
# 704              False             False                   False
# 705              False             False                   False
# 706              False             False                   False
#
#                                            description
# 0    Presenting Sharry Mann latest Punjabi Song  Cu...
# 1    पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...
# 2    Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 3    This video showcases the difference between pe...
# 4    why Samantha became EMOTIONAL @ Samantha naga ...
# ..                                                 ...
# 702  Seeman says his views and opinions about onlin...
# 703  In this episode of The Untitled Show, Actress ...
# 704  #SirPost.. This time our Letter is to Our Hono...
# 705  President Trump took a break mid-speech Wednes...
# 706  In This video you will know : How to grow long...
#
# [707 rows x 16 columns]

# %%
data = data.dropna()
print("Total views : ",data['views'].sum())
print("Total Likes : ", data['likes'].sum())

print("Total Dislikes : ",data['dislikes'].sum())
print("Total comments : ",data['comment_count'].sum())

print(data.sort_values(by = 'likes').head(1))

data['publish_time'] = pd.to_datetime(data['publish_time'])
data['year'] = data['publish_time'].dt.year

plt.scatter(data['year'],data['views'])
plt.xlabel("Years")
plt.ylabel("Views")
plt.show()

reacted = data['likes'].sum() + data['dislikes'].sum()
neutral = data['views'].sum() - reacted

plt.pie([reacted, neutral], labels = ['Reacted ', 'Neutral'],autopct = '% 1.2f%%')
plt.show()
# Out:
# Total views :  545735840
# Total Likes :  13215814
# Total Dislikes :  663218
# Total comments :  1385373
#         video_id trending_date  \
# 691  sEmUj8pm-b4      17.17.11
#
#                                                 title channel_title  \
# 691  16 November, 2017 Prelim Booster News Discussion      only ias
#
#      category_id              publish_time    tags  views  likes  dislikes  \
# 691           27 2017-11-16 07:39:59+00:00  [none]  18747      0         0
#
#      comment_count                                  thumbnail_link  \
# 691              0  https://i.ytimg.com/vi/sEmUj8pm-b4/default.jpg
#
#      comments_disabled  ratings_disabled  video_error_or_removed  \
# 691               True              True                   False
#
#                                            description  year
# 691  Subscribe to http://www.onlyias.com/\n\nLike u...  2017
